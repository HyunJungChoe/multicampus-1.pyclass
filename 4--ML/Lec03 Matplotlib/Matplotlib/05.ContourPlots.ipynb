# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(3)
y = np.arange(5)
x, y
# Out:
# (array([0, 1, 2]), array([0, 1, 2, 3, 4]))

# %%
x, y = np.meshgrid(x,y)

# %%
[list(zip(x,y)) for x, y in zip(x,y)]
# Out:
# [[(0, 0), (1, 0), (2, 0)],
#  [(0, 1), (1, 1), (2, 1)],
#  [(0, 2), (1, 2), (2, 2)],
#  [(0, 3), (1, 3), (2, 3)],
#  [(0, 4), (1, 4), (2, 4)]]

# %%
plt.scatter(x,y)

# %%
x = np.linspace(-2*np.pi, 2*np.pi)
y = np.linspace(0, 4*np.pi)

# %%
[x,y] = np.meshgrid(x,y)

# %%
z = np.sin(x)+np.cos(y)
plt.contour(x,y,z)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)
x,y = np.meshgrid(x,y)

# %%
z = np.sin(x)**10 + np.cos(10+y*x)*np.cos(x)

# %%
plt.contour(x,y,z, colors='k')
plt.show()

# %%
plt.contourf(x,y,z, 20, cmap='RdGy');

# %%
image = plt.imread('data/louvre.jpg')

# %%
plt.imshow(image);

# %%
plt.imshow(z, extent=[0,5,0,5], origin='lower', cmap='RdGy')
plt.colorbar()

# %%
contours = plt.contour(x,y,z, 3, colors='k')
plt.clabel(contours, inline=True, fontsize=8)
plt.imshow(z, extent=[0,5,0,5], origin='lower', cmap='RdGy', alpha=0.5)
plt.colorbar();

# %%
import pandas as pd

# %%
winequality = pd.read_csv('data/winequality.csv', delimiter=';')

# %%
corr = winequality.corr()

# %%
plt.figure(figsize=(12,9))
plt.imshow(corr, cmap='hot')
plt.colorbar()
plt.xticks(range(len(corr)),corr.columns, rotation=20);
plt.yticks(range(len(corr)),corr.columns);
